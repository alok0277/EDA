# %% [markdown]
# # Kunal

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.model_selection import train_test_split
from sklearn import metrics
import joblib

# %%
#importing pandas as pd
import pandas as pd

# Read and store content
# of an excel file
read_file = pd.read_excel ("cancer patient data sets.xlsx")

# Write the dataframe object
# into csv file
read_file.to_csv ("Test.csv",
				index = None,
				header=True)
	
# read csv file and convert
# into a dataframe object
df = pd.DataFrame(pd.read_csv("Test.csv"))

# show the dataframe
df
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# ...

# %%
#split dataset in features and target variable
feature_cols = ['Age','Gender','Air Pollution','Alcohol use', 'Dust Allergy', 'OccuPational Hazards','Genetic Risk']
x = df[feature_cols] #Features
y = df.Level #Target Variable

# %%
x.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk
# 0                     4             3
# 1                     3             4
# 2                     5             5
# 3                     7             6
# 4                     7             7

# %%
#Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
#create Decision Tree classifer object
dt = DecisionTreeClassifier(criterion="entropy", max_depth=3)

# Train Decision Tree Classifer
dt = dt.fit(X_train,y_train)

#predict the response for test dataset
y_pred = dt.predict(X_test)

print("Accuracy: ",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.76

# %%
pip install graphviz
# Out:
# ...
#      --------------------------------------- 47.0/47.0 kB 48.0 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dot_data = export_graphviz(dt, out_file=None,
                           feature_names=feature_cols,
                           class_names=['0','1', '-1'],
                           filled=True, rounded=True,
                           special_characters=True)

# %%
dot_data
# Out:
# 'digraph Tree {\nnode [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;\nedge [fontname="helvetica"] ;\n0 [label=<Alcohol use &le; 3.5<br/>entropy = 1.582<br/>samples = 700<br/>value = [250, 214, 236]<br/>class = 0>, fillcolor="#fefbf9"] ;\n1 [label=<Dust Allergy &le; 2.5<br/>entropy = 0.949<br/>samples = 310<br/>value = [0, 196, 114]<br/>class = 1>, fillcolor="#acf4ca"] ;\n0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;\n2 [label=<entropy = 0.0<br/>samples = 82<br/>value = [0, 82, 0]<br/>class = 1>, fillcolor="#39e581"] ;\n1 -> 2 ;\n3 [label=<Air Pollution &le; 3.5<br/>entropy = 1.0<br/>samples = 228<br/>value = [0, 114, 114]<br/>class = 1>, fillcolor="#ffffff"] ;\n1 -> 3 ;\n4 [label=<entropy = 0.988<br/>samples = 202<br/>value = [0, 88, 114]<br/>class = -1>, fillcolor="#e2d2f9"] ;\n3 -> 4 ;\n5 [label=<entropy = 0.0<br/>samples = 26<br/>value = [0, 26, 0]<br/>class = 1>, fillcolor="#39e581"] ;\n3 -> 5 ;\n6 [label=<Air Pollution &le; 1.5<br/>en
# ...

# %%
# Define a function for inputting ne data and getting predictions
def predict_lungcancer_outcome( index, Age, Gender, AirPollution, Alcoholuse, DustAllergy, OccuPationalHazards, GeneticRisk ):
  #Create a ne dataframe ith the input
  input_data = pd.DataFrame({
      'index': [index],
      'Age': [Age],
      'Gender': [Gender],
      'AirPollution': [AirPollution],
      'Alcoholuse': [Alcohouse],
      'DustAllergy': [DustAllergy],
      'OccuPationalHazards': [OccuPationalHazards],
      'GeneticRisk': [GeneticRisk]
  })

  predictions = clf.predict(input_data)

  return predictions[0]
